# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = 'Enter your api key here'

channel_ids = [ # Some Educational Channels
               'UCF7BExjT2zH_mmyqOB139Dg', # Apni Kaksha
               'UCVtL0esgwmD3bEZ2iNUjzHw', # Apni Kaksha NEET
               'UCmXZxX_qexEZxhb5_vQKPCw', # Aman Dhattarwal
               'UCBwmMxybNva6P_5VmxjzwqA', # Apna College
               'UCUNe-AifjeUt9QRn7lkgJ1g', # Apni Kaksha - 9th & 10th
               
               'UC7btqG2Ww0_2LwuQxpvo2HQ', # ProgrammingWithHarry
               'UCeVMnSShP_Iviwkknt83cww', # CodeWithHarry

               'UCZNNx4KYmCkwxCLdsHyWqQA', # Unacademy JEE
               'UC1ePkT4Kd_DrO1qK6-o0Qdg', # Unacademy Live - SSC Exams
               'UCABe2FgVNv2hgBeMu2mySVg', # Let's Crack UPSC CSE
               'UCdQwYksctqqiRwqp3PiJMWA', # Unacademy NEET
               'UCE6wlYZOldn_o25sXQzp0LA', # Unacademy - Shaurya
               'UCwFzHegPNQ8snevnmpzbv2w', # Unacademy CUET
               'UC4jZ2BALmfj-jaqVRTMqllg', # Unacademy Atoms
               'UCV1lbzgZNcYFAT3VHKOb7Cg', # Unacademy UPSC
               'UCa_AwYxequQ3Hek7qaITLgQ', # Unacademy Live - CSIR UGC NET
               'UCR3F3TPXHqXpotvmpyqXeQg', # Unacademy Class 11 & 12
               'UCFWCFYvqnAMT-jcCqTp_SlA', # Unacademy Computer Science
               'UC4SUQzurYVmGwgmfdn0yEVg', # Unacademy Class 9 & 10
               'UCPhY4iS6NNoQwlRLcUYu_tw', # Unacademy UPSC Hindi
               'UCjxQ7M1W2AL8hI_5JuxFYgA', # Unacademy - English Learning
               'UCrpELe0mluSZ8-2saJH5a0A', # Unacademy GATE - ME, PI, XE
               'UC2JNrw4j7Eo4R5cZXXn8rNw', # Unacademy CA Foundation Pro
               'UCBwwLyqbo6qTlDx5tS6Pl8w', # Unacademy CS Executive
               'UC7Y9ZsacCMna74LgYeVbDAQ', # Unacademy Class 6
               'UCONr9LnH0M3PA_VjchLNp1w', # Unacademy Live - IIT JAM
               'UCAgkv1L9uiXTskU8pl5TFDw', # Unacademy - लक्ष्य UPSC CSE
               
               'UCVJU_IChPMOe8RWkdVQjtfQ', # JEE Wallah
               'UCiGyWN6DEbnj2alu7iapuKQ', # Physics Wallah - Alakh Pandey
               'UCphU2bAGmw304CFAzy0Enuw', # Physics Wallah Foundation
               'UCD16eo98AXl-9T61Xd711kQ', # Competition Wallah
               'UC8zCnnfhz-dvIpVdZ1CheuA', # NCERT Wallah
               'UC8OCoGX9tmMneOzIFUTWq2Q', # Defence Wallah - NDA
               'UCko6jJyo-wUQmWhjGNAIrwg', # Physics Wallah - English
               'UCn5N03prvdzaZxEwq3AtHAw', # Commerce Wallah by PW

               'UCcabW7890RKJzL968QWEykA', # CS50
               'UCfzlCWGWYyIQ0aLC5w48gBQ', # sentdex

               'UCkw4JCwteGrDHIsyIIKo4tQ', # edureka!
               'UCywyZ4r4FTKExrPl9rf-ggw', # edureka! Hindi
               
               # Some Tech Channels
               'UCXUJJNoP1QupwsYIWFXmsZg', # Tech Burner
               'UCaSM4GqhbaVmRT7fmmFmR1w', # TechGumbo
               'UCXuqSBlHAE6Xw-yeJA0Tunw', # Linus Tech Tips
               'UCEPL07qzVsOcHd3sMUws65g', # Trakin Tech
               'UC1tVU8H153ZFO9eRsxdJlhA' # Technology Gyan
              ]

youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# Function to get channel status

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Description = response['items'][i]['snippet']['description'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads']
                    )
        all_data.append(data)
    
    return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data.dtypes
# Out:
# Channel_name    object
# Description     object
# playlist_id     object
# dtype: object

# %%
channel_data
# Out:
#                      Channel_name  \
# 0           Commerce Wallah by PW
# 1                    Apna College
# 2                            CS50
# 3     Unacademy GATE - ME, PI, XE
# 4                     Trakin Tech
# 5   Unacademy Live - CSIR UGC NET
# 6       Physics Wallah Foundation
# 7                       TechGumbo
# 8                 Linus Tech Tips
# 9                   Unacademy JEE
# 10                  CodeWithHarry
# 11       Unacademy Live - IIT JAM
# 12    Unacademy CA Foundation Pro
# 13                     JEE Wallah
# 14            Unacademy - Shaurya
# 15                 Unacademy UPSC
# 16           Defence Wallah - NDA
# 17                Aman Dhattarwal
# 18         Unacademy CS Executive
# 19                 Unacademy CUET
# 20           Let's Crack UPSC CSE
# 21   Unacademy - English Learning
# 22       Physics Wallah - English
# 23  Physics Wallah - Alakh Pandey
# 24                    Apni Kaksha
# 25    Unacademy - लक्ष्य UPSC CSE
# 26                        sentdex
# 27                    Tech Burner
# 28                Technology Gyan
# 29     Unacademy Live - SSC Exams
# 30         Unacademy Class 9 & 10
# 31                 edureka! Hindi
# 32     Unacademy Computer Science
# 33        Unacademy Class 11 & 12
# 34                       edureka!
# 35                Unacademy Atoms
# 36                 Unacademy NEET
# 37       Apni Kaksha - 9th & 10th
# 38               Apni Kaksha NEET
# 39           ProgrammingWithHarry
# 40           Unacademy UPSC Hindi
# 41             Competition Wallah
# 42                   NCERT Wallah
# 43              Unacademy Class 6
#
#                                           Description  \
# 0   Are you still searching for the best platform ...
# 1   Hey guys, welcome to this new channel - Apna C...
# 2   This is CS50, Harvard University's introductio...
# 3   👉 Click here to Enroll now and be a Topper : h...
# 4   Trakin Tech is one of the fastest growing Yout...
# 5   Hello learners,\n\nUnacademy Live - CSIR UGC N...
# 6   Are you in class 8, 9, class 10 and have fixed...
# 7   We are a technology channel dedicated to cover...
# 8   Looking for a Tech YouTuber?\n\nLinus Tech Tip...
# 9   Unacademy JEE is India's No.1 Channel for IIT ...
# 10  Code With Harry is my attempt to teach basics ...
# 11  Welcome to Unacademy Live - IIT JAM your one-s...
# 12  Welcome to Unacademy CA Foundation Pro, your o...
# 13  Are you looking for a platform to crack JEE 20...
# 14  Welcome to Unacademy Live  - CDS/AFCAT/CAPF, h...
# 15  Welcome to Uncademy UPSC, your one-stop soluti...
# 16  Welcome to our Defence Wallah channel, your on...
# 17  Hi friends,\nThis channel is regarding Class 1...
# 18  Welcome to Unacademy CS Executive Channel.\n\n...
# 19  Unacademy CUET is a one-stop solution for crac...
# 20  Welcome to Let's Crack UPSC CSE, your one-stop...
# 21
# 22  All your favorite Physics Wallah content. Now,...
# 23                                       Physics is ♡
# 24  Hey guys, we have created this channel to prov...
# 25  Welcome to Unacademy Lakshya UPSC!\n\nYour one...
# 26  Python Programming tutorials, going further th...
# 27  Tech Videos that count!\nJoin Us :)\nBrands an...
# 28  Subscribe for Interesting Tech Videos 😍 😍\n\nM...
# 29  Welcome to Unacademy Live - SSC Exams, your on...
# 30  Unacademy Class 9 and 10 brings to you the BES...
# 31  edureka! Hindi channel pe aapko milega high-qu...
# 32  Welcome to Unacademy Computer Science Channel,...
# 33  Unacademy Class 11 and 12 brings to you the BE...
# 34  Thank you for Subscribing! If you have not, Su...
# 35  Unacademy Atoms is the one-stop solution to yo...
# 36  Unacademy.com is India’s largest free educatio...
# 37
# 38
# 39  Programming With Harry is a place where you ca...
# 40  Welcome to Uncademy UPSC Hindi, your one-stop ...
# 41  Are you still searching for the best platform ...
# 42  NCERT Wallah contains top-notch educational vi...
# 43  Unacademy Class 6 channel brings you the best ...
#
#                  playlist_id
# 0   UUn5N03prvdzaZxEwq3AtHAw
# 1   UUBwmMxybNva6P_5VmxjzwqA
# 2   UUcabW7890RKJzL968QWEykA
# 3   UUrpELe0mluSZ8-2saJH5a0A
# 4   UUEPL07qzVsOcHd3sMUws65g
# 5   UUa_AwYxequQ3Hek7qaITLgQ
# 6   UUphU2bAGmw304CFAzy0Enuw
# 7   UUaSM4GqhbaVmRT7fmmFmR1w
# 8   UUXuqSBlHAE6Xw-yeJA0Tunw
# 9   UUZNNx4KYmCkwxCLdsHyWqQA
# 10  UUeVMnSShP_Iviwkknt83cww
# 11  UUONr9LnH0M3PA_VjchLNp1w
# 12  UU2JNrw4j7Eo4R5cZXXn8rNw
# 13  UUVJU_IChPMOe8RWkdVQjtfQ
# 14  UUE6wlYZOldn_o25sXQzp0LA
# 15  UUV1lbzgZNcYFAT3VHKOb7Cg
# 16  UU8OCoGX9tmMneOzIFUTWq2Q
# 17  UUmXZxX_qexEZxhb5_vQKPCw
# 18  UUBwwLyqbo6qTlDx5tS6Pl8w
# 19  UUwFzHegPNQ8snevnmpzbv2w
# 20  UUABe2FgVNv2hgBeMu2mySVg
# 21  UUjxQ7M1W2AL8hI_5JuxFYgA
# 22  UUko6jJyo-wUQmWhjGNAIrwg
# 23  UUiGyWN6DEbnj2alu7iapuKQ
# 24  UUF7BExjT2zH_mmyqOB139Dg
# 25  UUAgkv1L9uiXTskU8pl5TFDw
# 26  UUfzlCWGWYyIQ0aLC5w48gBQ
# 27  UUXUJJNoP1QupwsYIWFXmsZg
# 28  UU1tVU8H153ZFO9eRsxdJlhA
# 29  UU1ePkT4Kd_DrO1qK6-o0Qdg
# 30  UU4SUQzurYVmGwgmfdn0yEVg
# 31  UUywyZ4r4FTKExrPl9rf-ggw
# 32  UUFWCFYvqnAMT-jcCqTp_SlA
# 33  UUR3F3TPXHqXpotvmpyqXeQg
# 34  UUkw4JCwteGrDHIsyIIKo4tQ
# 35  UU4jZ2BALmfj-jaqVRTMqllg
# 36  UUdQwYksctqqiRwqp3PiJMWA
# 37  UUUNe-AifjeUt9QRn7lkgJ1g
# 38  UUVtL0esgwmD3bEZ2iNUjzHw
# 39  UU7btqG2Ww0_2LwuQxpvo2HQ
# 40  UUPhY4iS6NNoQwlRLcUYu_tw
# 41  UUD16eo98AXl-9T61Xd711kQ
# 42  UU8zCnnfhz-dvIpVdZ1CheuA
# 43  UU7Y9ZsacCMna74LgYeVbDAQ

# %%
# channel_data.to_csv('Channel_Data.txt')

# %%
# Change channel name here
channel_name = input("Enter Channel Name")
playlist_id = channel_data.loc[channel_data['Channel_name']==channel_name, 'playlist_id'].iloc[0]

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
video_ids
# Out:
# ['xyQqPaIBGAY',
#  'JFZfdHXxfjQ',
#  'rbZ3ikJDoDc',
#  'B1EzLskGr40',
#  'nJ3c1_R6Gf4',
#  'xdXlK_x3Xcs',
#  'aHJDj5h-frw',
#  'DHa9uCrRw6g',
#  '555zEwSQysA',
#  'HRAlHT-wz98',
#  'L2E7MGpYc8I',
#  'RUCANNX4xKA',
#  'jtBUqAlsvJ8',
#  'SVTbj1dZSjk',
#  'YDx_b55GBTA',
#  'Ju9gmM7Ss2Q',
#  'fxaoPWiUSBk',
#  '-iV3TlIgmnA',
#  'K-LsfCJISz4',
#  'US_Lx45rglk',
#  'gF-CSsMJ4PY',
#  'CcPem4ili3M',
#  '9PZaGkNBbLU',
#  'OIqirEIF5Uk',
#  'MDjc4HpFoc4',
#  'E6YPz0FTECg',
#  'OzSX5rBxbz8',
#  'kQXG4SR9GmA',
#  'M3YJFa_sUUs',
#  'XEFezzcxWj4',
#  'VpgWlYy4ARI',
#  'qStIMOjV4NI',
#  'I9NUtebvjoo',
#  '6A9sJt2C2SE',
#  '5_BBI329cXM',
#  'yAEOluL8LBA',
#  'wiep7kgL704',
#  'bMPocOw4haU',
#  't775iU-k67o',
#  'qzqdU1XagAQ',
#  'XYFUJAFUGB0',
#  'juHWwobVsII',
#  'IaC0GFaTuRM',
#  'XmvKmK8kH5U',
#  '48ayiuUTe4c',
#  'DZnzTYNxIzA',
#  'W89g2FY63EE',
#  'dxAOclK0R5A',
#  'o5ZJ8ywoN7w',
#  'RqdtbUMtUz8',
#  'WnmKHdSVW5I',
#  'zNNHD163guU',
#  'JDCEIJVS6jw',
#  'g7cNRECP14k',
#  '6ECNC_Ozm0o',
#  'lZ3P_6rQiNM',
#  'mWwXXrotwOU',
#  'vn_zK9mvl70',
#  'gvKk658b8Rk',
#  'AD3sur6QWFk',
#  'bAABhZO2bwM',
#  'uex1B6J-BP0',
#  'DZ-LD1bLbLI',
#  'B2_QZHDZixM',
#  '_0M1lgrezvk',
#  'JNEfSflv6uk',
#  'BswXraJuyMg',
#  'gKN6Or06Qfw',
#  'sKeau9bk0LU',
#  'OpMpcgfjVio',
#  'I6FT9E_k3PY',
#  'VVLu9jILSaY',
#  'GD7I8IS6TKM',
#  'bSlCIhouiC0',
#  'Bdn5ZDGiOTc',
#  'zULj-3vQuPs',
#  'h_QHU_DKTes',
#  'Gg0PN9r5E_M',
#  'dulbQyMyCW0',
#  'hEgd9CUtH2w',
#  'J0kQkwjGCFc',
#  'OjVW4WNcdqE',
#  '07m6V4eyFF8',
#  'hAh4zah3pqQ',
#  'dn1GLpcksTw',
#  'vZo6lgRgc8k',
#  'GZxujexhxoo',
#  'hWt7DAwxcvc',
#  'vI6OGKI6IKE',
#  'R3rgABGYsz0',
#  'WY_WuppgwHk',
#  '0BVL0wSckfI',
#  'mV09EgDVzds',
#  'C3StD3up2ik',
#  'xJYL0XtplYw',
#  '-764AryBzOA',
#  'foB_NRFyLBg',
#  'lCD7hAGbo58',
#  'His9Tjz2cSM',
#  'wwxKkJPnBN4',
#  'WDbodjpjr8o',
#  'e56cnUO3lYg',
#  'jh87cY3CR3c',
#  'YD3deFd07LQ',
#  'cBH7heO8jgs',
#  'gXwzDjHdobI',
#  '9XeHSt9ArFU',
#  'Ro0M0GMu-GQ',
#  'mwYjjF-RObs',
#  'SBAGUN5qtzQ',
#  'qUNmr0hyG4U',
#  'OlKQMWkXBlo',
#  'gInYE4cg_Gs',
#  'VCO5rUrazow',
#  'qRlwECD5s9c',
#  '-ZcHCaMyE7Y',
#  '_Nzgnz2eG-Q',
#  'tB-8r0jHb5s',
#  'hmdToMczziA',
#  '0_bII0OfNWA',
#  'Crx3DSXTSpc',
#  'BwyrtxB2koc',
#  'g1Y8TVDPZYA',
#  'BkHa7obSg0E',
#  '72KkUA-wRKk',
#  'vTkIFNnVpxk',
#  'xWNYl90-lis',
#  'kFT2sy3XBYA',
#  'gBiNxp9idRw',
#  'oJ2LKbpO_mQ',
#  'QtTfAoqIGXI',
#  'CbEzG6mlnMM',
#  'B9chn_2T-0M',
#  'pGE0oXMV6V0',
#  'E0_jBaFvdr4',
#  '2F4RwpqcdZ4',
#  'yCvhDwdWJwI',
#  '0YdYUL2ejEk',
#  'Djh_SMUiOB4',
#  'M-EUSkKvDt8',
#  'Af0YcLgpvnI',
#  'gC5Q9Y1PGKU',
#  'ZbIJB4JNeIA',
#  '5g__LBBEuKo',
#  '3daU_rP-Ldk',
#  'YNcgTV3UG98',
#  'ap4BnzymLgw',
#  '3evde9OUfj8',
#  'y_brrWqqAxE',
#  'fE2ZO6MNKYs',
#  'Y6fGyNr7R30',
#  '3So0GNPxTA0',
#  'P-8ougnDoOI',
#  '7_yfvoVSysc',
#  'tAgVDatHnRI',
#  'm6Dm3UmcpEs',
#  'xW_ulrMP-l0',
#  's4IjhaA30Bg',
#  'Gp5gdgB-aeo',
#  'b87Ph7j_GKI',
#  'RIImo08TpYY',
#  'HFeNkxInNTM',
#  'IyKoTCYQFV4',
#  'BSv6iw64eD4',
#  '_92f11Vmn8U',
#  'DN47RWtNNqA',
#  'ZUTUqX68Hs8',
#  'BSOR0B-9lAU',
#  'nTA_AHIsoaU',
#  'FfbEbNDFc6E',
#  'BSi2TqiXAgE',
#  'slQCpYdsQTQ',
#  'BfXuHRwj-Qk',
#  'TUatKDgcZHU',
#  'lqqtZOjoOPA',
#  '04f71Gn9Ieo',
#  'bFH4fEcEjoI',
#  'PUpPzZwsqC8',
#  'c_Df8C3NY6U',
#  'PUMJC9Bnih0',
#  'zDZKd2vui_4',
#  'E9_xDQ_-GE4',
#  '01rwR9LjytY',
#  'LM2UufCmnSg',
#  'Gpp_MfeORSY',
#  '0t8gNDyRwQk',
#  'VKJuASiAtkw',
#  'aLo8eqNB3SE',
#  'BRbv0-xBKhA',
#  '5NYlPEzhXvU',
#  'go8yUAY96gU',
#  'CUCClBYM664',
#  'ndhw3ljLVrQ',
#  '-5wF1GxdEBk',
#  'ru3IdDVFKK8',
#  'lgduehq2UtQ',
#  'Q6CkSClzh3E',
#  'GU4FXJn4wnk',
#  'fyEjcS91-8A',
#  '_QhoNN75iPk',
#  'IHnL_kX5x6A',
#  'jSLYk0utPJo',
#  '3blS2MmOOvE',
#  'wDO3JqIN08E',
#  'TWCPhRSWuRM',
#  'PfjXMBqQ67M',
#  'bYjQDuVeceI',
#  'Sly0VZ9QS40',
#  'RVsQRs71QxI',
#  'j6xEosUzenI',
#  'g0yNHLFEgX0',
#  'zAEUbWoIwRA',
#  'FiPqAeXlrjE',
#  'LSOaPG1AjxU',
#  '6gvKS7G_8QU',
#  'Sfi3H6lg2uo',
#  '4U7U6iLToY8',
#  'pK409lsw3RE',
#  'NBROuV2nmRY',
#  'ZI0TQnk6dXk',
#  '_8dr-HCguXY',
#  'xYTW9N4AWlM',
#  'WjzDEEwLm7Q',
#  '93ioRi-ug9o',
#  '8K4l9OLZO9w',
#  '2OyvJx0CyiA',
#  'yIKEObM0elM',
#  'sHQXVPsI_eA',
#  'NmCBZfDbLOE',
#  '87uWjv5mglE',
#  '9hP0UoZpA3I',
#  'eLa_IpXLBBs',
#  'FHzx_u7oYss',
#  'Z_aE4W_jVW0',
#  'Fr9lQbmhWp8',
#  'YCMmQouFkC8',
#  '3AV13z3YAg4',
#  'TTDZGtX9140',
#  'ToSZbEQS91s',
#  'YpGzLuhn2w4',
#  '6qipcatn6qo',
#  'V6N2gb032ow',
#  'bH4HdLpfq4s',
#  'GEwttD43dPE',
#  'dnx3IUA2wow',
#  'USzmM0c0LD0',
#  'H0th3YtCV_I',
#  '0noseQmMs4Y',
#  '4nv24CWaU2c',
#  't-CojHCiiss',
#  '8OE30XVU3og',
#  'ky7cXlyK3sE',
#  '2-lC30SiR2c',
#  'JbIjV85QZAk',
#  'Wu0pGvKyUr0',
#  '98UCE205rcQ',
#  'ACc7P1d0Y7E',
#  '2DSOaq5Hflk',
#  'RXWYaJ9gDv4',
#  'FEHxEPP1KJM',
#  'J_jaHpMONYk',
#  'vvfhfIVpqiI',
#  'GiXDO5Z1ZCM',
#  'dp0UM1ymsd4',
#  'Upca536KCf4',
#  'CE2WB6EMq2g',
#  'V8Wyj6bejOY',
#  'IvQWmexMFeo',
#  'jdXG-dO-0f0',
#  'IJcHoG21FU8',
#  'RGTnsHpk4l8',
#  'zA7thHlL3Cw',
#  'QubSo6zhrto',
#  'HJL_rwHeIOw',
#  '-ANTMqhyjbg',
#  'ta5olTD5De0',
#  'CkiRgXb8XT0',
#  'QpuwpnM7gh0',
#  '9K1Wm7CnVxE',
#  'F5g4dQ5W8K8',
#  'trJcThnpgm0',
#  'PnrTXaYZNQk',
#  '7bZASj2HfvA',
#  'fAWlnSbASrA',
#  'WGA2F_LizOI',
#  'VLtyUfalCBQ',
#  'YiFX1srsOKk',
#  'ekHaj6fglf4',
#  'GVucpd2wwco',
#  'q1--5mgAFfI',
#  'WEz-p_jOxS0',
#  'V1jrlsBM_ug',
#  'meBv3q-oUt8',
#  'oBXdaXkv34g',
#  'H4K6d9-yVz4',
#  'HirfOaB5tKI',
#  'jqHHoyMi-R8',
#  'ipHGSgbLNhM',
#  'ZVG1X9AmNtY',
#  'JmguBdc4ha4',
#  'k17LieeAOm8',
#  'yi-NApNzWAk',
#  'XYlJEsOtEZM',
#  '2Y4PHzoaATA',
#  'XkAwfySMkdc',
#  'nMLQkxqxz1w',
#  'eguRLEiS6Ws',
#  'fqxKh4OGhXE',
#  'mciLvzZXxSU',
#  'YDhlejZ2JWc',
#  'nhWnSG5DDI0',
#  'RBgHweXi7ts',
#  'mJUlj4I2CjA',
#  'G1kGjNynVgc',
#  'hlR-jXNDRyw',
#  '9nEL4qFCUdQ',
#  'a1FxzzpcQt4',
#  'qZzEI450QXo',
#  'Df1sbXrLVx4',
#  'whOZyjPj7b0',
#  'DDYwCDm0Rsk',
#  'QR0BBYuoF5Y',
#  'rXyTZ0G7sOk',
#  'qsP5GGmntpg',
#  'TXpA8wlktOM',
#  '9krpQew0yfs',
#  'Pp8FVrS7hU8',
#  'rpa5900OpQ4',
#  'MafElIE7qBs',
#  'LqstZ9UzUSk',
#  'IDTwg-oOdqo',
#  'pIcpvPw1JKQ',
#  'DjkPHvij3S0',
#  'dJiWcmLXBa0',
#  'JFbvpPf7BN4',
#  'XtCM_vfBY-w',
#  'BywXdNNO30Y',
#  '5Ayrv2WtAmY',
#  'bsZH0AK566Q',
#  'wNf-G3B_XZk',
#  'iG7JDrvr5iw',
#  '4DGRKyRE7RA',
#  '8ryF_Ro9dis',
#  'Ea0_Wik08gQ',
#  'lsvjUdokkqM',
#  'tmgFb0dRo24',
#  'BTcGv3aE5x0',
#  'xdwV1Pg3D5Y',
#  'cSJuwTCerSw',
#  'DiCo6J79LMU',
#  'wNb9bLuRYKs',
#  '-aTyUOvRAL4',
#  'x5avoQi-rr0',
#  'sed2P536kUM',
#  'eTjv_F0sqYs',
#  'MWY3IefZ0XQ',
#  'AGdT_MlWb4U',
#  'WTvJTjeLMmU',
#  '11qMsKrUFB0',
#  'vctKSOXTRtY',
#  'N0_LGoBkJ10',
#  'xf3HkF_7oic',
#  'Ff8qvW3tny4',
#  'MSE5h5Purgs',
#  'em7EqyipLnM',
#  'zIPBh8XhnSY',
#  '3KmTYAu7ZJA',
#  'EEPDckarI98',
#  '5zF2bCJ0aoE',
#  'grPWM9qJb44',
#  'AWR7zApNhGc',
#  'emgisEXt_pw',
#  'VZQ-vPliYxU',
#  '6j3W2Sq6JxQ',
#  'woUB-jeRdBw',
#  'O9LCF-UvMV8',
#  'MWGEcrzPM50',
#  'nbgiqprudr0',
#  '7e2uH4Ttyos',
#  'LkmQ9Tg3Jj0',
#  'LtXYgst4GHE',
#  'KvgmPMsgtXY',
#  'IdpNd9ModIY',
#  'SegSgDj-Rj8',
#  'MfcpyPLnzMY',
#  '8xjQCCHneYw',
#  'SA3wjfhC35c',
#  'mIwIiw6rVLQ',
#  'Du-ITu6F1ok',
#  'PGeE6X74l6g',
#  'IW4u5EDKaCY',
#  'fzGjbPAY--8',
#  'UEWXVZW1s7g',
#  'gFfvZ7EF9QM',
#  'X3IXuFTjNS0',
#  'e1Pp1pcvGOw',
#  'GAQmdLob4F8',
#  'zRqJk1IplvE',
#  'wD2coVbRigQ',
#  'e09IUzkEbb0',
#  '5poyDCt08A8',
#  'CigUd9zqTR0',
#  'yJZXuo2SunE',
#  'DChn3DkOkXo',
#  'U8HtgL1RhMs',
#  'bIwJ40dZ6xg',
#  '4orWKKPQRYo',
#  'yxyKaR_NZn0',
#  'vRgCXIV5_2M',
#  'OwSnFs0oQ7s',
#  'iGq7AAfCKEc',
#  '_ndHj4V5qb0',
#  'B2Ck0GQXmnc',
#  'nBU99ODNarc',
#  'OQPTsSweROk',
#  'Xl0K8jge9Tc',
#  'hcnSkCQM6_w',
#  'ylyaom1P6Cs',
#  'qubqzcwo0Y0',
#  'WyBUCab3TXE',
#  'zi6sfdl6EIQ',
#  'FGtOnM3fxxs',
#  '_lYr-7kSutY',
#  'cIGpSh5-Q9E',
#  'YkrmqL_PjM4',
#  'hrmIxtO5nw4',
#  'ec5Da-2yFZc',
#  'kV1gA9E2JTE',
#  'uTS0NJtoW0k',
#  'gc-ZNaoHUAk',
#  'XNIKAszJyYU',
#  'z5AC4XNHhSE',
#  'YUGguyqZ1-c',
#  'E87zGPAb25U',
#  'M8vdYa1Emxk',
#  'M4YQFG_aw2c',
#  'kWoCPrwM5lM',
#  'e2Sq61tI6bw',
#  '3xX997E42Ro',
#  'I-b0R7mhPZ4',
#  '7gl8VZXhox8',
#  'Jr---LnbiAs',
#  'dojp6VJSL8o',
#  'mKcVrtLkEeY',
#  'qb5Zr0gSMZ8',
#  'oELMrD8aJkM',
#  'S1dglDqU0qM',
#  '19ENgxmrbBY',
#  'jqKffQ6EMl0',
#  'm9u5TdydrV8',
#  'NmqoI7e59jE',
#  'dq4w08xOuII',
#  '_7_CRdquo2w',
#  'bohOFqwMGXI',
#  'QmJlLcS-UqM',
#  'IsEQ_3mUDCI',
#  'saQbKcW83WY',
#  '8G2eS62oQDE',
#  'YgdhGyl5Dz8',
#  'iqx46Yl9pLU',
#  'F3oX_YYIVpA',
#  'SWto81hBPC8',
#  'Ros_Jk4o2Nk',
#  'b0TPRvX2odU',
#  'gBFcBPu1ghU',
#  'zPLSVi6rEc0',
#  'BOTBt_LY-A8',
#  'yY8UAwSSp3w',
#  'rDHvvgLI5Ss',
#  'XgohfZ3WGwM',
#  'hzJSwgWQEBo',
#  '211uDjV9kjg',
#  'R8MYceAH69A',
#  'i9CJWmb-WLc',
#  'OAxdhXgHZEI',
#  'meByYOjfPFw',
#  'nkZ4KvyxupI',
#  'pov8Y_hAzj0',
#  'BC3PnxlUMWs',
#  'aXm05aFdmao',
#  'GlkcoLUYCVs',
#  'H7bDwI5nUl8',
#  'OhnnH7-68tk',
#  'a_Fs8QOPaxM',
#  '5eXqSQRiQHI',
#  '_G7yQoJoHUA',
#  'OXa5lBRoF7g',
#  'O_hu5Rej-Cg',
#  'M-AKHIQxATY',
#  'nlUgE7QxL-4',
#  'uTCn9DrXlck',
#  't3LRA17XO8Q',
#  'KsLNLLDGIws',
#  '11jJqfBHwTA',
#  '2K96DxnB3Vk',
#  'Igiyz_XT_UI',
#  'oEXGYh_k77M',
#  'KWq0647mb20',
#  'JbmLbnNk9PA',
#  'j785wY0RLUc',
#  'l2i4aio4FPM',
#  'LenjjS2fP-8',
#  'seZc-odV9g8',
#  '1X-pGYQRzVY',
#  'Lv_AtlnG54Q',
#  '7A2A7RiEPfo',
#  'O6R-lThrF7I',
#  '1SJwNKdB0Us',
#  'LOJbccqRmes',
#  '5phk9nuMF_Q',
#  'hzNM8BZ2rr0',
#  'ZLWpgaAKrTo',
#  'CqykKFK1THM',
#  '4V1usITZjJg',
#  'N2amCTxswBU',
#  'hjAm6jhEL3U',
#  'AtmD9bFgDD4',
#  '0LaFaksxC3k',
#  'yjs7aWHZuWM',
#  'YZa6uD1FOog',
#  'tXI6lqA_ElI',
#  '8jlvT2MY4do',
#  'LPP_TNJDcHE',
#  'Y0JgAzxsQ8Q',
#  '6rjXy_5LIW4',
#  'hN9pYBAiiV0',
#  '9Bak-hp24yw',
#  'c5z5bmJS7HQ',
#  'ygDVq-D1Tf0',
#  'xJbuYn8AuGk',
#  'ifwEYfg9h00',
#  '7lqq17aW-GY',
#  '8FH_oWNLpxE',
#  'DzhmNkro0LQ',
#  'HiMzAraw9KY',
#  'rD7HPN_ibew',
#  '9dx8v0kKcoU',
#  'Lvq9Wj_-K8M',
#  'fb4WTPPc5Bc',
#  '6dyeN5nqnVs',
#  '-C9ifmNM6Mc',
#  'I2ZNgf7zMFw',
#  '6uuJPVViF0g',
#  'XfiW84sBrY4',
#  'RMTNWfsSLiE',
#  'nVrzzntwheo',
#  'wyoQwt9HXok',
#  '7rf2oMokIAg',
#  'zB0rT_zfRN0',
#  'Ya7aYYmRfXo',
#  'ZsYhzVq5UTk',
#  '7ngjn1QXm-E',
#  '5H7P_DF9-c4',
#  'M-sYd7q2V9A',
#  'jVoqCgKms04',
#  '9nEeLZAL_Us',
#  'WVJJjVtEGqw',
#  'JqoBNGAZvFI',
#  'a2sMeAGFhqs',
#  'clLpzV6WKks',
#  'V5KE8jNMRkQ',
#  '1DJWZZfSPt0',
#  'SRn1usyU7TE',
#  '1bBz7J3wrZM',
#  'H6rYEdNBUp4',
#  '3d_ZIIrfY4k',
#  'lwMWaZBxifQ',
#  'S8g6LhHYjqo',
#  'qKfgnxwGqu0',
#  'IFZjbrtKQe4',
#  '9sEs7M0mvTs',
#  'IEimD2126-g',
#  'vlZGUgBJZME',
#  'yksl438aHp4',
#  'AfMEiLOQArM',
#  'vaCqYkj07RI',
#  'EQAXEjoV17E',
#  'YgpCbO4Tqf4',
#  'q5VudoHAdNI',
#  'GlHiiU47-NI',
#  'NJrNOLX4Otg',
#  'KqOp9HZoNWc',
#  'xvmPTuiiFvg',
#  'HNZYw5XJk-Y',
#  'v4Vc8qJaxes',
#  'K_cioTdK5-k',
#  '6QT-isK3pZk',
#  'Pej5XRR5QRA',
#  'nAMuj1T4Qh0',
#  'oS1BlGm91Bs',
#  'yU7ppEkhSsY',
#  'eJRNLA2Bu6M',
#  'hVMfcleQgn8',
#  'OG5Ok2Y-yEY',
#  'pOlBWXdv5S4',
#  'eBdns8sbh-U',
#  'DdBIT1_afKg',
#  'Trw1bAgiWMA',
#  'Eb6LrHHXDw4',
#  '4ueupqCunxc',
#  'b_LCoecrtYw',
#  '6UO45ZaCON4',
#  'b0I6qepvCeY',
#  '-G7bJVAIiEI',
#  'zmEh7cdQ3ec',
#  'q-qFYKVUkIc',
#  'MxR_a1JTimo',
#  'ACdu2Qc492Q',
#  'Y5Pw4uZfzcc',
#  'nXxYKdcprPw',
#  'iMT6fRMgOG0',
#  '2gdgOdw3bcw',
#  'UDfPI7JEOcs',
#  '-Ax4JxgPM3c',
#  '09jeEoU04gY',
#  'LTiF9KxRjm8',
#  '-sitdp-561E',
#  'mwyQKbfx5L4',
#  'zINEt0dTMX4',
#  'mADd58SMQZ4',
#  'OafYBhafmWA',
#  'A7428PATzKM',
#  '4DxlSudKsVo',
#  'gCHS0f4IiqY',
#  '3o9j-aFBH0w',
#  'zkdgEzLRIEk',
#  'PCume2IHHQM',
#  'PUPok5AZ0ek',
#  'OqF6-naf7nI',
#  '_nTetZcMR5g',
#  'HMiurYZJk_k',
#  '4Ez0Q9qf9hw',
#  'H6AcYGik7ok',
#  'dopAo415kd8',
#  'IBr3tM3lMyw',
#  '1NQ3gYAlA1M',
#  'WGoJxkhgYRQ',
#  'E-jxtCbAHLw',
#  '0BAs5aspUks',
#  'xF-KCabVOfs',
#  '5riirP72Bok',
#  'EF3amTCJ97c',
#  'kCDZArDdPRo',
#  'tXyCmnTHqg0',
#  '6VXwZ_Z4UTE',
#  'K0U0267_8_k',
#  'HyAEjFfMh8g',
#  'yOrRW3HG4vY',
#  'Wz9stOhy-5k',
#  'gqum5A0DFU0',
#  'NIVTgSdJCx0',
#  'l6s4bYQWvAk',
#  'X-E1GjMnZLs',
#  've3sKdnV5cE',
#  'NbTkJNzsGVg',
#  'EClNRbphO8s',
#  'muH3zoP8Lyk',
#  'ZqeE0PdNhjg',
#  'KLio0Y5ravo',
#  'XR7M5gsGsLU',
#  'TZ1nPsRDK7E',
#  'XfGkrUC-I74',
#  '37OHS5gUafs',
#  'U8_8fTODn5g',
#  'qRHE0aTQNs4',
#  'iAatHaYLTg8',
#  'OIWTfY0vAKQ',
#  'VjxjbbSfYh8',
#  'zo8UgPS8LtE',
#  'tkSeXTOTSCw',
#  'E583VXaY7w8',
#  'maQQDNDbQNc',
#  '4RAnWCjlvKo',
#  'IklnWwcjUrA',
#  'B45PaPTQ16A',
#  'BUv5xhQhgUE',
#  'uoigoHx8mVc',
#  'cWhov6RaWkY',
#  'd4HC_Wc8gbE',
#  'db-8WnQaOv8',
#  't-tUJhd5Abg',
#  'PXACt2Lr_6Y',
#  'BDQngtCATAU',
#  '2ENSOZOA2QY',
#  'NdsS2yeo5RI',
#  '453iZp7dil8',
#  'ZxTnLm2xvPA',
#  'OB5Es1Zsw4g',
#  'oIz3JdfF0ik',
#  'thNE1RNL_h0',
#  'eoZiMxh6mgQ',
#  'P7XT6v4Xrpc',
#  'PBZKVjw-P_A',
#  'yq1B04eLjY0',
#  'UJWba-1c5E4',
#  'WkcCu6HhIZ0',
#  'xSMM-neh_Y8',
#  'JYxuAQ3xmqQ',
#  'TV3NwhhTF6E',
#  'wm4CtXF9t5c',
#  'esF9uNXjjno',
#  '-sV29qAntFM',
#  '1aasLv1veU0',
#  'Owy2Gw7wgdw',
#  'JBOLgplBS6Q',
#  'Jy2Yj3EarbI',
#  'chI51l8dops',
#  '-a-yco89XJs',
#  '1_XoH_EbgXM',
#  'BiQpgnvC7rs',
#  '-1ljTmo0NkE',
#  'rUJMXvLQtrs',
#  'czARRiV-eKE',
#  'NwOn6MF6WgU',
#  'RMUGb5VdkbI',
#  'VAVIn6pQlBc',
#  '0EJQJMY8Hl0',
#  'WwlJQ5D0UhU',
#  '0WSxWfZckgI',
#  'JugvPCm8DR8',
#  'I9Q_BjiGpYc',
#  'g10Eixz3LBY',
#  'SSXHqWdHN2o',
#  'ji68VmmsG6M',
#  '3Nt2UIVxNvk',
#  'SM3lKWxdkOQ',
#  'WQknV8pcMhA',
#  'BErgt9dTNeE',
#  'YDMUqjrdmCU',
#  'VQU7-Pg_Rec',
#  'ILyWH3KTQiw',
#  '0FITtzuP1SU',
#  'dmtwYSYxxb0',
#  'cKjPTo-2Unw',
#  'Rlz9bCJWCg4',
#  'cAxindwgCxA',
#  'XONblklOLxA',
#  '7BHivhBFZQM',
#  'kKPLtta7Pbw',
#  'avJ1VSLEaew',
#  'CiHAItDQzQo',
#  'CUNMbHQ-1Wo',
#  'LQAf85AGBUA',
#  'Ac_t8iTrCjQ',
#  'BiqOac_A5Mw',
#  'kWlFc7cnLN4',
#  'h8HtUEyyO7g',
#  '3yVUGnrIHzQ',
#  'I--NB3pMsaY',
#  '9sB0gIUtyTw',
#  '3rWpiAU4o1w',
#  'cfpvlEuDc24',
#  'kFwOTzWxrNA',
#  's6vYODbuzVY',
#  'jdF1XBrDlCs',
#  'sXJbQsz1IDY',
#  '3knodmYcuTo',
#  'Y4UBGVxwMt0',
#  '4CIEhztSZa0',
#  'OV-Y1U0mkgg',
#  'skZESNirAWQ',
#  'sRkoJy_3sp0',
#  '76uH_mP0w00',
#  'ZGUI02YEaII',
#  'h3hxaGF-P7w',
#  'DoLTwHEXTpQ',
#  'HpbHDnD3f44',
#  'ewYtz_cKa1A',
#  'wYOFZPCr67U',
#  'xqsQtYFyxXY',
#  'FUtc-tJaOUM',
#  'I8wsigtzI6g',
#  'j_GyRwfkTHc',
#  'TeiNa7EHVHc',
#  'lFNJkVxWOYc',
#  'x_wCpT0IQHU',
#  'RkN6NgQE0vA',
#  'gbhJ995KdLk',
#  'db5Hz9lP8UQ',
#  'fNlg2STqtrA',
#  'QkyImA5IUPk',
#  'AVEWw1Fl6tg',
#  'j_We5qErIHw',
#  'ThnCVdGLdeI',
#  'liMCACLdzR8',
#  'MHjfvRvGtzw',
#  'qN_4woxoEgs',
#  'LC8KaLE4pwQ',
#  '7LmQ3e2uKK8',
#  '3i2NogG3sII',
#  'l9F3GVgEGzY',
#  '6_sB3r1pWHc',
#  '7sb-edyyjfU',
#  'Gwb0uNbXJZY',
#  'K-x86uUrTGs',
#  'UDrLTQzFWrc',
#  '192gA8F8ULM',
#  'Ed_BDawr4HM',
#  'TYIQLC0CFcs',
#  'md0ZJy3K5yI',
#  'frjI72nFrgY',
#  'ahVf3Oi7YzY',
#  'yf2sF2yEMR8',
#  'yxt7J3Nybf8',
#  '9XGK4GDEIsM',
#  'ZmhU4-RVxd4',
#  'LdctlfV1e-4',
#  'VXyTThWilvw',
#  'nlVwqMaLdSE',
#  'Epn0A0oQyeQ',
#  '_hVnsl8t7tk',
#  'ElKUw5ezLPI',
#  'v-wPymdgY10',
#  'vf6gBot7Dno',
#  'QkdfIN5XvJw',
#  'Q9O6IkDormY',
#  'jeDcBNL7ni0',
#  '4UkSp3hygfs',
#  'OYK2seqjBLo',
#  'taxCO9WdV8U',
#  'wiXV-n5beSo',
#  'heeGmu6cXsY',
#  '13ReH8ZATdg',
#  'scp5njXLjD0',
#  's2NT-N0FL9Y',
#  'LHuenwAFEWM',
#  '8iHkfqd1AUg',
#  'RNtZoWkZBfc',
#  'Nhr-S_RzWWc',
#  'gwjMgVTgFns',
#  'm_yRgneSons',
#  '6kTZiAZGiu4',
#  'PN49SehMXIc',
#  'qkKIP1EF5Bk',
#  'XvFJJoYYTYg',
#  'RBtGnM9Lqu8',
#  '2jX4I-aF9mU',
#  'AvtaWDGqcYc',
#  'd5KAoysae8w',
#  'mfREmAGUCcE',
#  'l0LX17F-kz0',
#  'q0LcSlw9Vtc',
#  'O29-q5ILytI',
#  'pvaDxPoRhaw',
#  'jqjUXCmjFpc',
#  '-c-ksmd_rDs',
#  'tEeUIbzi3a4',
#  '97LB8PCk9aI',
#  'Fz4urngSbZM',
#  '_kFhhiXrklg',
#  'x6PHrlc6HXY',
#  '0f8-uDowX34',
#  '0iT_n-pSotg',
#  'SvAYBJK7Z3c',
#  'hmZMPRwfIHA',
#  'IaeGLIAc3rs',
#  'tlVbfN-WWtE',
#  'tWE8kpaaTmA',
#  'iRsJ7QLu8nA',
#  'ojR8Pn804Wo',
#  'wikQrIKDvFg',
#  '0s53uOtfNa8',
#  'nMYapL6RQzU',
#  '19zs6ZRU0F8',
#  'Vf1wDMA95eQ',
#  'oUouIen_rwg',
#  'x6wF5jEhmXk',
#  'PIYPtc2kGo4',
#  '5gVdmq3cbaY',
#  'q_7LBwtry64',
#  '2_QHMpEet4w',
#  'BIPpLhr9GCQ',
#  'bNq6zuQsA2M',
#  '__YzSk9Iw48',
#  'i8H2RRQnncQ',
#  '01By5eVUVBg',
#  'Ba6NbshbSRs',
#  'rcZStEJkdQc',
#  '_zyCz9X1rsI',
#  'eBTXZGuX4II',
#  'RUHQGEgOLu0',
#  'sidS_QwIOP0',
#  '6MXsVddUM5g',
#  '0rjyCqz_vs0',
#  'kb-sTij9hxk',
#  'srle_XzpCHA',
#  'npZsQxEYPWs',
#  'zgTiT0OZnjk',
#  'xdIF1lU29ZM',
#  '56QxyFoun4Q',
#  '1SMZWOhtvgQ',
#  '0a0X8fZyJ2A',
#  '8Vxnb7myTCk',
#  'Ynz1efAi5XU',
#  'YUDXGY-NeU4',
#  'hN2GgA4oj00',
#  'Hz0uy_CcfSw',
#  'UyY2K113o5U',
#  '8nWrBfn6_1s',
#  '65PJhFgo1fc',
#  'Fun8Luq8bYM',
#  '2tDijbHKUF0',
#  'YNOeqsM_yxI',
#  'T1D9Q-twZg0',
#  'FO2iNaPsZvk',
#  'jgA1ul_6pqQ',
#  'Ia1TwDgfOQM',
#  'V0Ft6-F5z7g',
#  'DhoeXXGGjA8',
#  'rtdXZ7oHi64',
#  '6ZQ72xb7PCQ',
#  '4eJ_O6aNaCs',
#  'YTye785iUKE',
#  'L2aQhC-GVvw',
#  'LjxpyijwMqg',
#  '9OxBoa6vDPA',
#  'ShrYDpVH0qQ',
#  'DXdM8xY_NR4',
#  '0vxBOurSBwc',
#  'hs2VlWVN3j8',
#  'T_ww2APuFJI',
#  'SwomT12QXCo',
#  'fkZONFOfqK0',
#  'uApwayjfQ3g',
#  'TGgEdk_2dtM',
#  'MVV1EEmXMF0',
#  'zxxoTHVINaE',
#  'UIHH2--BDII',
#  'Y-MvMBm6jhU',
#  'EzoR1ISggvI',
#  'v1rbyQQzupY',
#  'PDGGg-Pp_cI',
#  'oPv_7e7JJgg',
#  '8iQq2JX9pu0']

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids[i:i+50]))
        response = request.execute()
        
        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                               Description = video['snippet']['description']
                               )
            all_video_stats.append(video_stats)
            
    
    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data
# Out:
#                                                  Title  \
# 0    Snapdragon 888 Phone at ₹26,999 - Crazy Festiv...
# 1                     Apple iPhone 14 Pro is here.....
# 2    This 12,499 New POCO Phone is Budget Champ? *L...
# 3            ₹99 Pass to Buy A New Phone * Explained *
# 4    This 24,999 Flagship Killer Phone - Deserves Y...
# ..                                                 ...
# 929  How To Convert Video song to Mp3 Song Without ...
# 930  What is Root ? advantage and disadvantage of R...
# 931  How To Root/Unroot Any Android Mobile Without ...
# 932      How To Add Subscribe Button in Youtube videos
# 933  How To Use Free 3G internet on Mobile ? Mobile...
#
#                                            Description
# 0    Snapdragon 888 Phone at ₹26,999 - Crazy Festiv...
# 1    is video mein hamne apple ke newly phone iphon...
# 2    POCO M5 Unboxing & quick review : is video mei...
# 3    is video mein mene flipkart ke taraf se aane w...
# 4    is video mein mene xiaomi ke ek old flagship k...
# ..                                                 ...
# 929  video गाने  को Mp3 गाने मे केसे बदले वो भी बिन...
# 930  what is root ?\nwhat is the advantage and disa...
# 931  ROOT And Unroot any Android Phone Without pc  ...
# 932  How To Add subscribe button in all youtube vid...
# 933  Download app here :\nhttp://catchhow.com/free-...
#
# [934 rows x 2 columns]

# %%
# To csv
# file_name_csv = 'Video_Details('+channel_name+').csv'
# video_data.to_csv(file_name_csv)
# To txt
file_name_txt = 'Video_Details('+channel_name+').txt'
video_data.to_csv(file_name_txt)

# %%
import re
f1 = open('Video_Details('+channel_name+').txt','r', encoding="utf8")
lines = f1.read()
s1 = re.sub('http://\S+|https://\S+', ' ', lines)
s2 = re.sub('http[s]?://\S+', ' ', s1)
s3 = re.sub(r"http\S+", " ", s2)
f1.close()


f2 = open('Video_Details('+channel_name+').txt','w', encoding="utf8")
f2.write(s3)
f2.close()
