# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = 'Enter youy API key here'

channel_ids = [ # Some Educational Channels
               'UCF7BExjT2zH_mmyqOB139Dg', # Apni Kaksha
               'UCVtL0esgwmD3bEZ2iNUjzHw', # Apni Kaksha NEET
               'UCmXZxX_qexEZxhb5_vQKPCw', # Aman Dhattarwal
               'UCBwmMxybNva6P_5VmxjzwqA', # Apna College
               'UCUNe-AifjeUt9QRn7lkgJ1g', # Apni Kaksha - 9th & 10th
               
               'UC7btqG2Ww0_2LwuQxpvo2HQ', # ProgrammingWithHarry
               'UCeVMnSShP_Iviwkknt83cww', # CodeWithHarry

               'UCZNNx4KYmCkwxCLdsHyWqQA', # Unacademy JEE
               'UC1ePkT4Kd_DrO1qK6-o0Qdg', # Unacademy Live - SSC Exams
               'UCABe2FgVNv2hgBeMu2mySVg', # Let's Crack UPSC CSE
               'UCdQwYksctqqiRwqp3PiJMWA', # Unacademy NEET
               'UCE6wlYZOldn_o25sXQzp0LA', # Unacademy - Shaurya
               'UCwFzHegPNQ8snevnmpzbv2w', # Unacademy CUET
               'UC4jZ2BALmfj-jaqVRTMqllg', # Unacademy Atoms
               'UCV1lbzgZNcYFAT3VHKOb7Cg', # Unacademy UPSC
               'UCa_AwYxequQ3Hek7qaITLgQ', # Unacademy Live - CSIR UGC NET
               'UCR3F3TPXHqXpotvmpyqXeQg', # Unacademy Class 11 & 12
               'UCFWCFYvqnAMT-jcCqTp_SlA', # Unacademy Computer Science
               'UC4SUQzurYVmGwgmfdn0yEVg', # Unacademy Class 9 & 10
               'UCPhY4iS6NNoQwlRLcUYu_tw', # Unacademy UPSC Hindi
               'UCjxQ7M1W2AL8hI_5JuxFYgA', # Unacademy - English Learning
               'UCrpELe0mluSZ8-2saJH5a0A', # Unacademy GATE - ME, PI, XE
               'UC2JNrw4j7Eo4R5cZXXn8rNw', # Unacademy CA Foundation Pro
               'UCBwwLyqbo6qTlDx5tS6Pl8w', # Unacademy CS Executive
               'UC7Y9ZsacCMna74LgYeVbDAQ', # Unacademy Class 6
               'UCONr9LnH0M3PA_VjchLNp1w', # Unacademy Live - IIT JAM
               'UCAgkv1L9uiXTskU8pl5TFDw', # Unacademy - लक्ष्य UPSC CSE
               
               'UCVJU_IChPMOe8RWkdVQjtfQ', # JEE Wallah
               'UCiGyWN6DEbnj2alu7iapuKQ', # Physics Wallah - Alakh Pandey
               'UCphU2bAGmw304CFAzy0Enuw', # Physics Wallah Foundation
               'UCD16eo98AXl-9T61Xd711kQ', # Competition Wallah
               'UC8zCnnfhz-dvIpVdZ1CheuA', # NCERT Wallah
               'UC8OCoGX9tmMneOzIFUTWq2Q', # Defence Wallah - NDA
               'UCko6jJyo-wUQmWhjGNAIrwg', # Physics Wallah - English
               'UCn5N03prvdzaZxEwq3AtHAw', # Commerce Wallah by PW

               'UCcabW7890RKJzL968QWEykA', # CS50
               'UCfzlCWGWYyIQ0aLC5w48gBQ', # sentdex

               'UCkw4JCwteGrDHIsyIIKo4tQ', # edureka!
               'UCywyZ4r4FTKExrPl9rf-ggw', # edureka! Hindi
               
               # Some Tech Channels
               'UCXUJJNoP1QupwsYIWFXmsZg', # Tech Burner
               'UCaSM4GqhbaVmRT7fmmFmR1w', # TechGumbo
               'UCXuqSBlHAE6Xw-yeJA0Tunw', # Linus Tech Tips
               'UCEPL07qzVsOcHd3sMUws65g', # Trakin Tech
               'UC1tVU8H153ZFO9eRsxdJlhA' # Technology Gyan
              ]

youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# Function to get channel status

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Description = response['items'][i]['snippet']['description'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads']
                    )
        all_data.append(data)
    
    return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data.dtypes
# Out:
# Channel_name    object
# Description     object
# playlist_id     object
# dtype: object

# %%
channel_data
# Out:
#                      Channel_name  \
# 0                      JEE Wallah
# 1                    NCERT Wallah
# 2            Let's Crack UPSC CSE
# 3                  Unacademy NEET
# 4      Unacademy Live - SSC Exams
# 5   Unacademy Live - CSIR UGC NET
# 6          Unacademy CS Executive
# 7                            CS50
# 8                 Technology Gyan
# 9     Unacademy GATE - ME, PI, XE
# 10           Defence Wallah - NDA
# 11                        sentdex
# 12                 edureka! Hindi
# 13                Linus Tech Tips
# 14                    Tech Burner
# 15              Unacademy Class 6
# 16         Unacademy Class 9 & 10
# 17                  Unacademy JEE
# 18            Unacademy - Shaurya
# 19    Unacademy CA Foundation Pro
# 20                  CodeWithHarry
# 21                Unacademy Atoms
# 22                    Apni Kaksha
# 23                Aman Dhattarwal
# 24       Physics Wallah - English
# 25                   Apna College
# 26               Apni Kaksha NEET
# 27                 Unacademy UPSC
# 28                    Trakin Tech
# 29           Unacademy UPSC Hindi
# 30      Physics Wallah Foundation
# 31                      TechGumbo
# 32          Commerce Wallah by PW
# 33    Unacademy - लक्ष्य UPSC CSE
# 34     Unacademy Computer Science
# 35  Physics Wallah - Alakh Pandey
# 36   Unacademy - English Learning
# 37           ProgrammingWithHarry
# 38       Apni Kaksha - 9th & 10th
# 39       Unacademy Live - IIT JAM
# 40        Unacademy Class 11 & 12
# 41                 Unacademy CUET
# 42                       edureka!
# 43             Competition Wallah
#
#                                           Description  \
# 0   Are you looking for a platform to crack JEE 20...
# 1   NCERT Wallah contains top-notch educational vi...
# 2   Welcome to Let's Crack UPSC CSE, your one-stop...
# 3   Unacademy.com is India’s largest free educatio...
# 4   Welcome to Unacademy Live - SSC Exams, your on...
# 5   Hello learners,\n\nUnacademy Live - CSIR UGC N...
# 6   Welcome to Unacademy CS Executive Channel.\n\n...
# 7   This is CS50, Harvard University's introductio...
# 8   Subscribe for Interesting Tech Videos 😍 😍\n\nM...
# 9   👉 Click here to Enroll now and be a Topper : h...
# 10  Welcome to our Defence Wallah channel, your on...
# 11  Python Programming tutorials, going further th...
# 12  edureka! Hindi channel pe aapko milega high-qu...
# 13  Looking for a Tech YouTuber?\n\nLinus Tech Tip...
# 14  Tech Videos that count!\nJoin Us :)\nBrands an...
# 15  Unacademy Class 6 channel brings you the best ...
# 16  Unacademy Class 9 and 10 brings to you the BES...
# 17  Unacademy JEE is India's No.1 Channel for IIT ...
# 18  Welcome to Unacademy Live  - CDS/AFCAT/CAPF, h...
# 19  Welcome to Unacademy CA Foundation Pro, your o...
# 20  Code With Harry is my attempt to teach basics ...
# 21  Unacademy Atoms is the one-stop solution to yo...
# 22  Hey guys, we have created this channel to prov...
# 23  Hi friends,\nThis channel is regarding Class 1...
# 24  All your favorite Physics Wallah content. Now,...
# 25  Hey guys, welcome to this new channel - Apna C...
# 26
# 27  Welcome to Uncademy UPSC, your one-stop soluti...
# 28  Trakin Tech is one of the fastest growing Yout...
# 29  Welcome to Uncademy UPSC Hindi, your one-stop ...
# 30  Are you in class 8, 9, class 10 and have fixed...
# 31  We are a technology channel dedicated to cover...
# 32  Are you still searching for the best platform ...
# 33  Welcome to Unacademy Lakshya UPSC!\n\nYour one...
# 34  Welcome to Unacademy Computer Science Channel,...
# 35                                       Physics is ♡
# 36
# 37  Programming With Harry is a place where you ca...
# 38
# 39  Welcome to Unacademy Live - IIT JAM your one-s...
# 40  Unacademy Class 11 and 12 brings to you the BE...
# 41  Unacademy CUET is a one-stop solution for crac...
# 42  Thank you for Subscribing! If you have not, Su...
# 43  Are you still searching for the best platform ...
#
#                  playlist_id
# 0   UUVJU_IChPMOe8RWkdVQjtfQ
# 1   UU8zCnnfhz-dvIpVdZ1CheuA
# 2   UUABe2FgVNv2hgBeMu2mySVg
# 3   UUdQwYksctqqiRwqp3PiJMWA
# 4   UU1ePkT4Kd_DrO1qK6-o0Qdg
# 5   UUa_AwYxequQ3Hek7qaITLgQ
# 6   UUBwwLyqbo6qTlDx5tS6Pl8w
# 7   UUcabW7890RKJzL968QWEykA
# 8   UU1tVU8H153ZFO9eRsxdJlhA
# 9   UUrpELe0mluSZ8-2saJH5a0A
# 10  UU8OCoGX9tmMneOzIFUTWq2Q
# 11  UUfzlCWGWYyIQ0aLC5w48gBQ
# 12  UUywyZ4r4FTKExrPl9rf-ggw
# 13  UUXuqSBlHAE6Xw-yeJA0Tunw
# 14  UUXUJJNoP1QupwsYIWFXmsZg
# 15  UU7Y9ZsacCMna74LgYeVbDAQ
# 16  UU4SUQzurYVmGwgmfdn0yEVg
# 17  UUZNNx4KYmCkwxCLdsHyWqQA
# 18  UUE6wlYZOldn_o25sXQzp0LA
# 19  UU2JNrw4j7Eo4R5cZXXn8rNw
# 20  UUeVMnSShP_Iviwkknt83cww
# 21  UU4jZ2BALmfj-jaqVRTMqllg
# 22  UUF7BExjT2zH_mmyqOB139Dg
# 23  UUmXZxX_qexEZxhb5_vQKPCw
# 24  UUko6jJyo-wUQmWhjGNAIrwg
# 25  UUBwmMxybNva6P_5VmxjzwqA
# 26  UUVtL0esgwmD3bEZ2iNUjzHw
# 27  UUV1lbzgZNcYFAT3VHKOb7Cg
# 28  UUEPL07qzVsOcHd3sMUws65g
# 29  UUPhY4iS6NNoQwlRLcUYu_tw
# 30  UUphU2bAGmw304CFAzy0Enuw
# 31  UUaSM4GqhbaVmRT7fmmFmR1w
# 32  UUn5N03prvdzaZxEwq3AtHAw
# 33  UUAgkv1L9uiXTskU8pl5TFDw
# 34  UUFWCFYvqnAMT-jcCqTp_SlA
# 35  UUiGyWN6DEbnj2alu7iapuKQ
# 36  UUjxQ7M1W2AL8hI_5JuxFYgA
# 37  UU7btqG2Ww0_2LwuQxpvo2HQ
# 38  UUUNe-AifjeUt9QRn7lkgJ1g
# 39  UUONr9LnH0M3PA_VjchLNp1w
# 40  UUR3F3TPXHqXpotvmpyqXeQg
# 41  UUwFzHegPNQ8snevnmpzbv2w
# 42  UUkw4JCwteGrDHIsyIIKo4tQ
# 43  UUD16eo98AXl-9T61Xd711kQ

# %%
channel_data.to_csv('Channel_Data.txt')

# %%
# Change channel name here
channel_name = input("Enter Channel Name")
playlist_id = channel_data.loc[channel_data['Channel_name']==channel_name, 'playlist_id'].iloc[0]

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
video_ids
# Out:
# ['0C7Wx5cLEiQ',
#  'Pt1KGG26RKU',
#  's3xw_c2i34s',
#  'kQI7rwIIWyw',
#  '3OxllpMRU9E',
#  '5sa738YvYVE',
#  '7zitoUc_rd8',
#  'Huyv89BHFow',
#  'FKVf1E78Wb8',
#  '5i-etFWWlCE',
#  'Zn9URTEJGf8',
#  'DhbAlnVd98g',
#  '2-XBpzYLqB4',
#  'ZFoCzPU7GSQ',
#  '_hC-upJ5aAE',
#  'WeF3_nk-UqY',
#  'tTQFObPYa-w',
#  'RUwn-5hrQQM',
#  'JbNOjPjQQEM',
#  'WGlFrt9FiJE',
#  '4x7dVcCWkmI',
#  '1BDWECwY64Q',
#  'UOJZTqA5Loc',
#  'H7gSdQ9ipd0',
#  'mQPwauiXFUo',
#  'eJiGN1h8XzM',
#  '2JQn9QxU1-s',
#  'yogmzgas5xc',
#  '2UZ_veozgS4',
#  'jIrG-OxhnQ8',
#  'BSGcQi2WNPg',
#  'PIGrPkNPz1k',
#  'gUIc2eE0lRA',
#  'PBN3Cv2Aq8Y',
#  'JYnEbcTCyVI',
#  'amk-ClIuQKI',
#  '7vPd1ArdeiU',
#  'xeUuJzHwqyQ',
#  'Qkrt-tKBl9k',
#  'xj3QNYuKFK4',
#  'xh79e5mA2Yo',
#  'qAeitQWjNNg',
#  'kE1sWLcoL60',
#  'RXk9tndVOAg',
#  'Y9oGAVuc2To',
#  '3xC0F9bj9FU',
#  'iELBsXEt2vc',
#  'bR17XCHEGBI',
#  'RB8hM6MG77U',
#  'fYnO6NJdpWM',
#  'TU-13Dzv9pM',
#  'rFxlfWO7CWk',
#  'VVvVxMOrh14',
#  '9FT8ZeF44YM',
#  'u6Xsayqxij0',
#  'KwDmdz7UIXg',
#  'AgyTHzjBS-c',
#  'O_CxjHkAelg',
#  'afV7FP_1wbk',
#  'jp9uVuD0J4c',
#  'P0xi93jIi9s',
#  'TpN9XEStbNQ',
#  'WAjxrgYGs6g',
#  'WUc-HnOWmVQ',
#  'MkcfB7S4fq0',
#  'djYrmRzQMeE',
#  'UbIhprsWYKI',
#  'Ckpp9kRV2Z8',
#  'vouCwkWaog4',
#  'YL7bhSCb9gk',
#  'SYQtz23NACQ',
#  'HYJZ0CYw3hk',
#  'AjCJtT_qkKI',
#  'X-cdWlx7hQI',
#  '4HaeFkzfy20',
#  '5-V0-y1iP3Q',
#  '9lkQUS2bPCY',
#  'ElCkr9BOkG8',
#  'kE5QWhrNjqY',
#  'hIiz8Km2tpo',
#  'uULy2rc6YDc',
#  'TEnks7wOBKs',
#  'px7PkuWSrLw',
#  '83NgW2D8dfY',
#  'HcOc7P5BMi4',
#  'aqja_mp_A9Q',
#  't8ffBh0B2ak',
#  '83BgsqvQzkQ',
#  'ZejKrRhE6qA',
#  'irqbmMNs2Bo',
#  'FckrkTwzzjs',
#  'LVFQu_piWsE',
#  'p_5TWTNOtUQ',
#  'pZdIiVDeAgU',
#  'sAlxN59cwXA',
#  'hzdc6NIMdTY',
#  'GLEoU0FfTPw',
#  'zlZ_dupXxE0',
#  'nDXX6LIJx8A',
#  'KUv_AAUea7E',
#  'yUaJCjiPBnY',
#  'zTgYjW5roxk',
#  'GOiDf1wSMts',
#  'szhSdCifQgE',
#  'C4bOz88QG5w',
#  '1NqKgTxJwDQ',
#  '-DzowlcaUmE',
#  'VmiwbpD-TYc',
#  'j1Hivf4wsgw',
#  'xtg75m7NfZQ',
#  '4bIwBQVK5dc',
#  'tG7Zk0HntYM',
#  'N_qGjCQwjJo',
#  '_0hhgW4YCLs',
#  'eKqY-oP1d_Y',
#  'OLVUrgQ_BbA',
#  'B-x1hnmTn8E',
#  'NJUQNWpObkg',
#  '_N6j8HXPt2U',
#  'AtKGZyJ_sbc',
#  'va_6RmSrKCg',
#  'D2-puZiUyyI',
#  'w9gwV8cCMaQ',
#  'ZB-7eq4txjA',
#  'PrHhMytCgG8',
#  'iH3P3HeF6pE',
#  'pPb8RYMHbbA',
#  'ToZSFHUJdHM',
#  '6uWgManShNw',
#  'EFUD2MulXY0',
#  'MsP19NXyw7g',
#  'RNh8VHc8qkk',
#  '7m1DMYAbdiY',
#  '_T4Y4vbjysE',
#  'rJ1iA-33fss',
#  'p_5Hu51STk4',
#  'gY5sGvq-8h8',
#  'QXum8HQd_l4',
#  '5QUSeBAMjoo',
#  'unxAnJBy12Q',
#  'fYvmhGTfQzs',
#  'U4p-QIvl1-8',
#  'tRj4VlVTat8',
#  'iuh8-dGrFbE',
#  'rJ1Qao09CFI',
#  'vLqTf2b6GZw',
#  'bRs6E_SL2Tk',
#  'otkpUBKqCCQ',
#  'lCRFpaykm9I',
#  'Dm0K3x9yCkg',
#  'tGDQuWDk2Z8',
#  '3qCJOWspNnU',
#  'pCj0Jr-ktp4',
#  'cL4gHVuFOvk',
#  '-203GRSHJ3Y',
#  'WM4qpxQ71KQ',
#  't7YaoQOFXzk',
#  'u49MZH-FFa4',
#  'oAja8-Ulz6o',
#  'XuGaq24wixg',
#  'VphowcSkBX4',
#  '2l_8ZKRfz_k',
#  'bP7ZBMYpRwc',
#  'P_e_6rL3kgk',
#  'liFyhzZl9uw',
#  'fYR3i0mcE5c',
#  'jtn-hRJjl68',
#  'MvEBc_60OmM',
#  'PkJIc5tBRUE',
#  '4ZSL8_zlq9Y',
#  'shoQfc0cJp4',
#  'aHPK2rsonZA',
#  '101q0HoCDKs',
#  'bSrm9RXwBaI',
#  'koNiEIfo5jY',
#  'jX8PbaReV5Q',
#  '7n8kPBPzy5I',
#  'jfC_Ih_hYIA',
#  'tBisiZf885o',
#  'OSoO8eCEEC8',
#  'jOn8kv7SaZ8',
#  'GXONlNAnmNU',
#  'aDflzFzyg3Q',
#  'XrAyzuNanZo',
#  'A4sxvx5NBuk',
#  'Oud4alVQU4s',
#  'PHAGTPlew_k',
#  '4zL85-xylG4',
#  'QrFYRTcKXAU',
#  '0QSSUHTJ-sU',
#  'ojHJK6K_EdA',
#  'ZLDwskEhIFg',
#  'iZen_amj7OE',
#  'xw0J0v3Zkuo',
#  'vCRD36bG8xQ',
#  'QIKQEKm0qIE',
#  'wioAFuHzcao',
#  'VoofwdxrTt4',
#  '18Zt5I4S45o',
#  'LgZZLeWKGsI',
#  'vP3TRAsjZss',
#  '4RjmmZnDFVA',
#  'NTHVTY6w2Co',
#  'bQssdSrSGNE',
#  'N8GASXniB6A',
#  'Ibx2Ri5Blh0',
#  'pFPZ83mgH00',
#  'qcSz4ef9UHA',
#  'vCZqAriaPZw',
#  'Dr4PpNa7AYo',
#  'vldRjjbcRXc',
#  'GjHNGM7KN3w',
#  'QaRxPjoeqL8',
#  '0r1SfRoLuzU',
#  'I5srDu75h_M',
#  'LusTv0RlnSU',
#  'yRpLlJmRo2w',
#  'UZ32p89gH4A',
#  'xZykmhcWGuY',
#  'cQYtzhaMvpA',
#  '0hQPN4OQgU4',
#  'Z9U8e1OVsw8',
#  'uBypDN_Zr5I',
#  'oBLNuNmRy5U',
#  'u-HgzgYe8KA',
#  '5kY4Th53w70',
#  'yGrslRzyR78',
#  '7xgJmIOG8GE',
#  '4_QfNyWEV8g',
#  'drt2sG-HQx4',
#  'B67X9xtOyuI',
#  'VsEfh-EqNT8',
#  'KZehm-meGMg',
#  '5Boqfjissv0',
#  'aRFFOZxW8v0',
#  'e91hGbJ1AuY',
#  '34sQVC7QD4U',
#  'Bs4w_o07wEo',
#  'WrBh3FSdgB8',
#  '8C_kHJ5YEiA',
#  'w8GEq18N1uU',
#  'hg38QLJbmuc',
#  'ImGxZx12U4E',
#  'bN6DE-4uFNo',
#  'n0kikYKo3nA',
#  'DJckAUyEwR0',
#  'vU3dL1cNqgQ',
#  '_FFRRMEXdBU',
#  'f88s33eFGDo',
#  'iBOzTJaIoNM',
#  'iNHbQ0diNZc',
#  'XPedtcrgA4E',
#  'hvPbIo09OTE',
#  '0Cu9Kg7RJYg',
#  'NreaqzAKvg0',
#  'gfwMYLQaZP0',
#  'tuxMRkKuP8Y',
#  'PxbTUonOEME',
#  'ktP8QsPzKfs',
#  'qvwdpqVvcRQ',
#  'kRfoq_9XJKY',
#  '08HzVTjCAsk',
#  'sTk5BxgxDDI',
#  'fIQABUIeWYg',
#  'qTph1pj_rCo',
#  'YH4aS0F0D8c',
#  'zSt-KI0HryY',
#  'lPWCLJLokzs',
#  'f1oV46r69YM',
#  'UmnCZ7-9yDY',
#  'iAvORz4ApbY',
#  'Hu2UlulDGuI',
#  'Hooe5ORdFsc',
#  'JdakjlFEAxc',
#  'WYiYkl-vPzo',
#  '1AHKqRrJ8_s',
#  'hRaDYCHqFQQ',
#  'LYuJ2aT0UcY',
#  'uqBgvO5DAUc',
#  'bJhVFE-KhHc',
#  '2lRQTdpwhFk',
#  'uZEbkca2yFM',
#  'j8fubBAFq_I',
#  'B7wHpNUUT4Y',
#  'payOcHP24NY',
#  'hcyzxsV4xsk',
#  'nTOoQsvQLqg',
#  'c6GDAgiX5Yw',
#  'h2zzRpibjpE',
#  'xOogmSgym9Y',
#  'N5mvpJGyUQg',
#  'cwdt9RrGSoQ',
#  '-WdkLyTeZ3Q',
#  'YrkBJ1ptdP4',
#  'lhhqbGH7Pao',
#  'MG5ZhaFWat0',
#  'q2HYCMeUXXQ',
#  'KnBwHYAnbEw',
#  'JEOj8U54Cek',
#  '1vsmaEfbnoE',
#  'IwlAhfeSnp8',
#  '8uU5ewUst50',
#  'jyd4uH5dWJ8',
#  'oBH9dH6KGLM',
#  'RNwMeijExjg',
#  '5NxYn0GiApg',
#  'nwUOmzFh78o',
#  '8-80h4cSb4Q',
#  '-siXttWLVto',
#  'US1_VVD98Vw',
#  'iMZEwYfBWDY',
#  'jWD-BQmbhkk',
#  'YJyXfjbBmc8',
#  '0oP6XLTI2tY',
#  'xcsDEn2G-tY',
#  'akoIMy9NmFc',
#  'IpQW7GWLxYA',
#  'A22wPijWmvw',
#  'dOXfffhl4uI',
#  'AWfLtXPQjhE',
#  'uVGrbtm69Vo',
#  'okH3HAPWTVs',
#  'eFhsSqzbpjI',
#  'VzO_ueJZqXc',
#  '86F87X8iRd0',
#  'XGa4onZP66Q',
#  'CB8w6MzXsx4',
#  'qXNJD7giQmU',
#  'zgphvsIBMz4',
#  'g1uZPKKrm3U',
#  'Em87pVL5qGM',
#  '0cjO51vAY44',
#  '-g_xhI_tZfA',
#  'Esx-TxF5PSo',
#  'okgM58Tv9jQ',
#  'PPcpC5QbMx0',
#  '0zvG6bIZ5KY',
#  '6PxU4rfnf4Q',
#  'GBBRjI_1LRI',
#  'EoMxK6zh9wU',
#  'YkBch12jNE0',
#  '37Aiwud-Jks',
#  'sPeKpctCL-c',
#  '_KLesu_89Ec',
#  'jcMMi4bBeVo',
#  'wjv-w6q4ip4',
#  'q9cXEL_I7Zo',
#  'LKfIjVZ6kg4',
#  'SnZ2SQARTVI',
#  'qCBMiADrmlY',
#  'IU5L8oePljw',
#  'J7nUacHWtsM',
#  'z52TfBnBrhQ',
#  'YZ40AZQi0bk',
#  'kfEJsL2ETik',
#  'C0O8T3C8irU',
#  'orl8SsQOToc',
#  'nY-VMGp72NI',
#  'hGscdp38JKM',
#  'KWEwNfFrrk4',
#  'SRIVJzucPoU',
#  'Yh5o_PSK9to',
#  'GmZNp9_-imM',
#  'geOBaNYYInc',
#  '3pr9Ce9vECc',
#  'ymMZEudHUsk',
#  'eGc5TQpBMjA',
#  'pS6xaqaLuCU',
#  'trZjhJk4LxM',
#  'so1E0lSytz0',
#  'mhaXVXFjsgI',
#  '2i5pclQprGk',
#  'DHr-Mn_vzs0',
#  'IUQRh7SJwEM',
#  'bDPtZO_Skyc',
#  'q79pZ_iwP50',
#  'bZ5Sif6L7Jg',
#  'osxiwsEahzE',
#  'y-ua1zS9wU0',
#  'pTxn1q80yAU',
#  '5g03Ydcwseg',
#  'oGsohYOOfRQ',
#  '2yCsrWvHcKQ',
#  'oJx-w2CB8d4',
#  'wQzCgzA1TKw',
#  '0kfM_YEzR94',
#  'Yqh1DadzGXU',
#  'VV19JFP6-0c',
#  'NIUgvZxt3Lg',
#  'XzA5Ts_vXfw',
#  'MMTQz-G8e-I',
#  'MCuERE9Ewbo',
#  'PiSs-3z9LUY',
#  'PsdZOG9dJic',
#  'd75iHEzPx8k',
#  'b7wMv62Y1l4',
#  'nvE5kQVdLc4',
#  'KWDUOForS2s',
#  'Iqjo4PNQT7A',
#  'U4vEszMVNsM',
#  'tck6hjcFzzc',
#  'ddWKdSS5TaQ',
#  'xP_aCKJtFPg',
#  'F3Cpo4Cc04A',
#  'eI3lzXlmH2U',
#  'YgC-IXiMrRM',
#  'ftBT8kH-QtM',
#  'xtuhK-a18is',
#  '1ZAotQGnbi4',
#  'C59kWTK4_Zs',
#  '_XgTN72fguk',
#  'DUiYVJIVNcA',
#  'vFW80O0NzBU',
#  'kU9Lv3e_kxs',
#  'ywK_wgQwKJY',
#  'ScdwdSCnXDU',
#  'NIJN63astRc',
#  'JW-9nhktGGA',
#  'f-oTsCUCiXk',
#  'WR6-DrAsNpc',
#  'E1f9ncPxgPE',
#  'zDkNaQYusu0',
#  'jeJTgKPydAw',
#  'bh4eb_6SwRA',
#  'xDayqPCWmkY',
#  '9fj_-Sr84CU',
#  'IHfZaRZFg7s',
#  'IZa8pbR8CWs',
#  'vQIiUWofWw8',
#  'PJX9T2oVKmk',
#  'HJKoNLGRnYk',
#  '67zlUtAr2LE',
#  'rW0mnUpA26U',
#  '_jKa4gycZTw',
#  'T-Oj2Ajj9vA',
#  '7FE5Q_Bqzw8',
#  'BCLfxQja9dI',
#  'XlD5VsOZsyA',
#  'rlCSjCGc3Z0',
#  'BsPbCLj4_Mw',
#  'Xdhdgl0Ju4k',
#  '0cBvL1U9QNo',
#  'fyy2Mr84vNM',
#  'YtxLexm-9pI',
#  'tMfy0tQ2HHk',
#  'hGl8Boeb7S4',
#  '4JstGzs6Q9I',
#  'KhPJ5xF4gIk',
#  '8imJZHgf44E',
#  'AJCse3XPkrY',
#  'xBSlwwitD5U',
#  'eKtwlzRyuIc',
#  'hFvf0iPOjT8',
#  'FbPIay0KN00',
#  'OGkaHOD6CRU',
#  'iuI0SKPT35Y',
#  'iEwX3XA5SDo',
#  'Yi8Im4_eSQI',
#  'fbonDkYsKj0',
#  'zts6uNVnCNs',
#  '9wad39LmzPY',
#  'P31WyOcQvaE',
#  'j5Q7gVtTy3M',
#  'snDDBjT8jYA',
#  '5B6jw4wOJR0',
#  'MuF5p8-oWc8',
#  '6T3jMNUCRNU',
#  'mg9yi6YuAVk',
#  'V2reKQOgE88',
#  'D_YpGeDy-i8',
#  'k1O1PhuarpI',
#  'Hkoml2mXDD8',
#  'JvuaAgDar1c',
#  'lcPs2BbbI_M',
#  'oZ-ZIhJyy9o',
#  's2fwy4ri0RU',
#  'TaNfBSbpX_o',
#  '1t8NAjIXvVA',
#  'IHeY7XMfXCc',
#  'xpoWxFyGuC8',
#  'V5rEOX-PuPE',
#  '2WMRDUS_b4E',
#  'p870o46o1bM',
#  '5plesRICYTI',
#  'n5_9DMCX0Yk',
#  'l-EkcthUMl4',
#  '8CACsqPWpHo',
#  'v6g1g4lNowM',
#  'c_dqAyQu84A',
#  'bgKYobOXTZ0',
#  '6Cpd63_WXdI',
#  'Fj1ywT9ETQk',
#  'LCRGV8avvUY',
#  'wKPlQkOdpFQ',
#  'C01LeeMhwHc',
#  'bjtMCwy_LMA',
#  '4nC4VXHlys8',
#  'kvk8gfAJLeg',
#  'sqJ6xZ9mUwE',
#  'Crqgl10aIGQ',
#  'cja3Hd3bwmY',
#  '61ppyY5rUB0',
#  'F5PbnZkHqmg',
#  'jRAZlTEZi9I',
#  '7ZfEp71tIec',
#  '2QR11oDukn4',
#  'Rek0NWPCNOc',
#  'l1EssrLxt7E',
#  'YscEcXRmBoY',
#  'N97M67GQTwI',
#  '2C4CQ32961Y',
#  'sV4RhDIIKO0',
#  'imqr13aIBAY',
#  'Dl6HT-NM_q4',
#  '14WBmf9nMsk',
#  '4z9I6ZmeLOQ',
#  'yoZy5RicIPc',
#  '4UIAOMWoD3I',
#  '1OkZKjxRokU',
#  '4BBB0mvvbGA',
#  '28okqq8raXM',
#  'MjPurvtUs7U',
#  'WZ6ZhiCg2_Q',
#  'VQVeAQVs1d8',
#  '9rt-hFcXd0M',
#  '16uXCDeRvMU',
#  'j9RG18jfnRY',
#  'Sp0RJLGrBm4',
#  '7F3MYyw3Jmg',
#  'oSQbwlepoCU',
#  'IW4hJEgZLWI',
#  'nDPo9hsDNvU',
#  'WEpLyOc0bCE',
#  's8l8NWII3qw',
#  'MiJdgxTWaFs',
#  '1pVI0yiEBR8',
#  'W8hPsBquD6Y',
#  'CF1j_wMEbPA',
#  'bbym08gSWvQ',
#  'gHxmAgedyDk',
#  'TkTgo_7ab0M',
#  'xKZFAkSt2UU',
#  'tIAydH3NnJk',
#  'Xx1tWbb37hY',
#  '0JYgnhnZFcE',
#  'kJW_iXrwePE',
#  'eJcBH0xvG98',
#  '3GC83dh4cf0',
#  'xcPFUCh0jT0',
#  'dQa4A2Z0_Ro',
#  '13ocRMSJy5M',
#  'PyTK_g1l8V8',
#  'rq_rwnveh8s',
#  'lYnPK1svd-4',
#  '8vzk_JBKGcQ',
#  '83KtncYgHYQ',
#  '6TzUHrAXytM',
#  '0yn7irrHzM8',
#  'QIyugGzih4k',
#  'k9OlCJFy5yo',
#  'LfgAOZ1kKMw',
#  'JBgZxnAj4hg',
#  'G80-j_xnE_8',
#  'Stf7KBiA1vs',
#  'IlIn_D1RT7M',
#  'cyB3HNlQyjY',
#  '7dPdMtBX1d8',
#  'cnT1oW5_ePM',
#  'z9bZufPHFLU',
#  'v4EtpkayVMY',
#  'j0biLzzJ2XQ',
#  'ODMqCXOO-eE',
#  'k2oGoqxRLaw',
#  '7rtvYQEAbIo',
#  'zGJ5BlbKfLM',
#  '1VfqlKtVF7U',
#  'Y8Lk3Gi-ugo']

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids[i:i+50]))
        response = request.execute()
        
        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                               Description = video['snippet']['description']
                               )
            all_video_stats.append(video_stats)
            
    
    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data
# Out:
#                                                  Title  \
# 0    How to Balance College Life? Is Multi-tasking ...
# 1              What to do in College? 1st Year RoadMap
# 2    Should I pay for an Internship? For College St...
# 3                      Tech Companies that got Hacked!
# 4          Don't wait for Motivation, lead with Action
# ..                                                 ...
# 572  Watch this before buying Laptop | Best Budget ...
# 573  IAS at 23 | How to study for UPSC CSE during C...
# 574  Is VIT Vellore Good? | All about VIT Vellore |...
# 575     IIT DELHI College Review | All about IIT Delhi
# 576  India's Top 70 Engineering Colleges | College ...
#
#                                            Description
# 0    #shorts\nAre you worried about placements/inte...
# 1    Are you worried about placements/internships? ...
# 2    #shorts\nAre you worried about placements/inte...
# 3
# 4    #shorts\nAre you worried about placements/inte...
# ..                                                 ...
# 572  Link to the Laptop PDF : https://drive.google....
# 573  0:00 Intro \n1:27 School & Colleg Life\n8:29 M...
# 574  Link to the PDF : https://drive.google.com/fil...
# 575  Are you worried about placements/internships? ...
# 576  Are you worried about placements/internships? ...
#
# [577 rows x 2 columns]

# %%
# To csv
# file_name_csv = 'Video_Details('+channel_name+').csv'
# video_data.to_csv(file_name_csv)
# To txt
file_name_txt = 'Video_Details('+channel_name+').txt'
video_data.to_csv(file_name_txt)

# %%
import re
f1 = open('Video_Details('+channel_name+').txt','r', encoding="utf8")
lines = f1.read()
s1 = re.sub('http://\S+|https://\S+', ' ', lines)
s2 = re.sub('http[s]?://\S+', ' ', s1)
s3 = re.sub(r"http\S+", " ", s2)
f1.close()


f2 = open('Video_Details('+channel_name+').txt','w', encoding="utf8")
f2.write(s3)
f2.close()
